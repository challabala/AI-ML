# %% [markdown]
# <a href="https://colab.research.google.com/github/challabala/AI-ML/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Basics**

# %%
print("hello world")
# Out:
# hello world

# %%
print(20+20)
# Out:
# 40

# %%
print("balaji"+" challa")
# Out:
# balaji challa
